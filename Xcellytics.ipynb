# %% [markdown]
# # 🚀 Sales & Product Intelligence System — Foundation Notes
#
# ## 📌 Project Overview
#
# We are building a SaaS-based system that helps businesses:
#
# * Track sales (pipeline & completed)
# * Manage products and pricing
# * Record expenses (general + confidential)
# * Analyze revenue, profit, and performance
# * Visualize data through dashboards
#
# ---
#
# ## 🎯 Core Goal
#
# To transform manual Excel-based tracking into an automated, intelligent system that improves:
#
# * Decision making
# * Sales performance
# * Profitability
#
# ---
#
# ## 🧱 System Modules
#
# ### 1. Product Management
#
# * Add unlimited products
# * Edit product price anytime
#
# ### 2. Sales Management
#
# * Record sales (quantity, product, date)
# * Track status (pipeline or completed)
# * Auto-calculate totals
#
# ### 3. Expense Management
#
# * General expenses (visible)
# * Confidential expenses (admin only)
#
# ### 4. Performance Summary
#
# * Revenue (with & without expenses)
# * Profit calculations
# * Target tracking (Green / Yellow / Red)
#
# ### 5. Dashboard
#
# * Product performance
# * Revenue trends
# * Monthly analytics
# * Visual charts
#
# ---
#
# ## 🛠️ Tech Stack
#
# ### Backend:
#
# * FastAPI
# * SQLAlchemy
# * Pydantic
#
# ### Database:
#
# * SQLite (initial)
# * PostgreSQL (later)
#
# ### Frontend:
#
# * HTML / CSS / JavaScript
#
# ### Data Analysis:
#
# * Pandas
# * Plotly / Matplotlib
#
# ---
#
# ## 🔐 Future Features
#
# * Authentication (Login system)
# * Role-based access (Admin vs User)
# * Email onboarding (Free trial system)
# * AI predictions & recommendations
#
# ---
#
# ## 🧭 Development Strategy
#
# ### Phase 1 (MVP)
#
# * Build core system (products, sales, expenses)
#
# ### Phase 2
#
# * Add dashboard & analytics
#
# ### Phase 3
#
# * Add authentication & SaaS features
#
# ### Phase 4
#
# * Add AI intelligence
#
# ---
#
# ## ⚠️ Key Principle
#
# We are not just building a tracker.
# We are building a system that collects valuable data for future AI insights.

# %%
#Step 1 Seting Up 

# Installing libraries

# !pip install fastapi uvicorn sqlalchemy pydantic
# Out:
# ...
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Database Setup

# DATABASE SETUP (RUN THIS FIRST)

from sqlalchemy import create_engine
from sqlalchemy.orm import declarative_base, sessionmaker

DATABASE_URL = "sqlite:///./sales.db"

engine = create_engine(DATABASE_URL, connect_args={"check_same_thread": False})

SessionLocal = sessionmaker(bind=engine)

Base = declarative_base()

# %%
# First Model --- Prodcts Table

# models.py equivalent
# MODELS (DO NOT IMPORT Base)

from sqlalchemy import Column, Integer, String, Float

class Product(Base):
    __tablename__ = "products"

    id = Column(Integer, primary_key=True, index=True)
    name = Column(String, index=True)
    price = Column(Float)

# %%
# CREATE TABLES

Base.metadata.create_all(bind=engine)

# %%
from pydantic import BaseModel

class ProductCreate(BaseModel):
    name: str
    price: float

# %%
from fastapi import FastAPI, Depends
from sqlalchemy.orm import Session

# Create tables (Base already defined earlier)
Base.metadata.create_all(bind=engine)

app = FastAPI()

# Dependency
def get_db():
    db = SessionLocal()
    try:
        yield db
    finally:
        db.close()

# Root endpoint
@app.get("/")
def read_root():
    return {"message": "Sales System API is running 🚀"}

# Create product
@app.post("/products/")
def create_product(product: ProductCreate, db: Session = Depends(get_db)):
    db_product = Product(name=product.name, price=product.price)
    db.add(db_product)
    db.commit()
    db.refresh(db_product)
    return db_product

# %%
# !pip install pytz
# Out:
# ...
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # Step 3 — Analytics & Decision-Making Layer
#
# ## Purpose
# Transform raw sales data into summaries and insights for management:
# - Daily totals
# - Monthly totals
# - Product-level performance
# - Target tracking
#
# ## Features
# 1. Aggregate sales per day
# 2. Aggregate sales per product
# 3. Aggregate monthly totals
# 4. Show pipeline vs completed
# 5. Prepare data for dashboard (graphs, charts, tables)
#
# ## Outcome
# - Dashboard-ready API endpoints
# - Accurate business metrics
# - Insights for decision-making

# %% [markdown]
# ### STEP 4 — PROFIT, EXPENSES & TARGETS
#
# Features we are adding:
#
# Expenses
#
# Daily/general expenses
#
# Confidential expenses (protected)
#
# Profit calculation
#
# Revenue minus expenses
#
# Targets
#
# Compare actual revenue vs target
#
# Return status: green / yellow / red
#
#
# Dashboard-ready endpoints
#
# Monthly product revenue & profit
#
# Total monthly profit
#
# Target tracking

# %% [markdown]
# # Step 5 — Professional Frontend Notes
#
# ## Goals
# - Clean, responsive UI
# - Real-time dashboard
# - CRUD for products, sales, expenses
# - Visual targets and status (green/yellow/red)
# - Professional SaaS feel
#
# ## Pages
# 1. Login / Free trial request
# 2. Dashboard overview:
#    - Monthly revenue per product
#    - Total profit
#    - Target status badges
# 3. Products management:
#    - List products
#    - Edit price & targets
# 4. Sales input:
#    - Select product
#    - Enter quantity
#    - Mark status
# 5. Expenses input:
#    - Normal expenses
#    - Confidential expenses (password protected / admin only)
#
# ## Components
# - Sidebar / NavBar
# - Cards for KPIs
# - Line/Bar charts for monthly revenue
# - Data tables for sales & expenses
# - Badges for status colors
#
# ## Libraries / Tools
# - React.js
# - TailwindCSS (styling)
# - Recharts or Chart.js (charts)
# - Axios (API calls)
# - React Router (navigation)

# %% [markdown]
# sales-dashboard/
# ├─ public/
# ├─ src/
# │  ├─ components/
# │  │  ├─ Navbar.jsx
# │  │  ├─ Sidebar.jsx
# │  │  ├─ DashboardCard.jsx
# │  │  ├─ SalesTable.jsx
# │  │  ├─ ExpensesTable.jsx
# │  │  └─ ProductForm.jsx
# │  ├─ pages/
# │  │  ├─ Login.jsx
# │  │  ├─ Dashboard.jsx
# │  │  ├─ Products.jsx
# │  │  ├─ Sales.jsx
# │  │  └─ Expenses.jsx
# │  ├─ App.jsx
# │  └─ api.js        # axios instance for FastAPI
# ├─ package.json
# └─ tailwind.config.js

# %%
3gyKT9K7uVBztNVoGqHZogGvLGAbfhD4MPfHZAeGpump
